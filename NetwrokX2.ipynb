# %%
import networkx as nx
import matplotlib.pyplot as plt
import random
def create_network(city_set,costs,num_edges):
    G=nx.Graph()
    for each in city_set:
        G.add_node(each)
    while(G.number_of_edges()<num_edges):
        c1=random.choice(list(G.nodes()))
        c2=random.choice(list(G.nodes()))
        if c1!=c2 and G.has_edge(c1,c2)==0:
            w=random.choice(costs)
            G.add_edge(c1,c2,weight=w)
    return G
city_set=["Raipur","Bhilai","Durg","Bilaspur","Rajnandgaon","Korba","Raigarh","Jagdalpur","Ambikapur"]
costs=[]
value=100
while(value<=2000):
    costs.append(value)
    value=value+100
    
print(costs)
G=create_network(city_set,costs,12)
pos=nx.spring_layout(G)
nx.draw(G,pos,with_labels=True)
nx.draw_networkx_edge_labels(G,pos,edge_labels=nx.get_edge_attributes(G,'weight'))
plt.show()

u="Raipur"
v="Durg"
print(nx.dijkstra_path(G,u,v))
print(nx.dijkstra_path_length(G,u,v))
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000]
# ['Raipur', 'Ambikapur', 'Durg']
# 1800
